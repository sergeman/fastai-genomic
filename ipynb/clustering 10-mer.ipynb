# %% [markdown]
# ## Exploration of Dna2Vec embedding space for bacterial genomes; 10-mers

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../mylib/")

from genomic import sequence
from genomic.sequence import regex_filter, count_filter
from functools import partial
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import manifold,neighbors
from scipy.cluster.hierarchy import dendrogram, linkage  
from matplotlib import pyplot as plt
import seaborn as sns; sns.set(color_codes=True)
import plotly.plotly as py
import plotly.graph_objs as go
from mpl_toolkits.mplot3d import Axes3D

# %%
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec
word_vectors = Word2Vec.load_word2vec_format('/data/genomes/embeddings/dna2vec-20190612-1611-k10to10-100d-10c-4870Mbp-sliding-kPR.w2v')  # C text fordmat

# %%
from collections import Counter
def to_color(d):
    return 0. if "A" not in d.keys() else d["A"]/10.,   0. if "G" not in d.keys() else d["G"]/10., 0. if "C" not in d.keys() else d["C"]/10., 0.1 if "T" not in d.keys() else d["T"]/9.
kmers=list(word_vectors.wv.vocab.keys())[::100]
X=word_vectors[kmers]
X.shape

counts = [Counter(k) for k in kmers]
colors = [to_color(d) for d in counts]

# %%
tsne = manifold.TSNE(n_components=3, init='pca', random_state=0)
# %time X_tsne = tsne.fit_transform(X)
# Out:
# CPU times: user 9min 28s, sys: 1.13 s, total: 9min 29s
# Wall time: 9min 29s

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X_tsne[:,0],X_tsne[:,1],X_tsne[:,2],marker=".", c=colors,s=80)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title("Word2Vec embedding of 10-mers of bacterial genome")
ax.legend(['A - redness G - greenness C - blueness  T - transparency'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-700bbc6ae21c> in <module>
# ----> 1 fig = plt.figure(figsize=(20,20))
#       2 ax = fig.add_subplot(111,projection='3d')
#       3 ax.scatter(X_tsne[:,0],X_tsne[:,1],X_tsne[:,2],marker=".", c=colors,s=80)
#       4 ax.set_xlabel('PC1')
#       5 ax.set_ylabel('PC2')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Load Data

# %%
filters=[partial(regex_filter, rx="Streptomyces|Bacillus|Vibrio|Streptococcus|Rhizobium|Staphylococcus"),partial(regex_filter, rx="plasmid", keep=False)]
data = sequence.Dna2VecList.from_folder("/data/genomes/GenSeq_fastas",filters=filters,agg=partial(np.mean, axis=0),n_cpus=7,emb=word_vectors)
processors = [
    sequence.GSFileProcessor(),
    sequence.GSTokenizeProcessor(tokenizer=sequence.GSTokenizer(ngram=10, skip=0, n_cpus=7)),
    sequence.Dna2VecProcessor(emb=word_vectors)]
for p in processors:
    print("\n", type(p))
    # %time p.process(data)
# Out:
#  <class 'genomic.sequence.GSFileProcessor'>
# CPU times: user 1.01 s, sys: 136 ms, total: 1.15 s
# Wall time: 1.77 s
#
#  <class 'genomic.sequence.GSTokenizeProcessor'>
# CPU times: user 6.68 s, sys: 300 ms, total: 6.98 s
# Wall time: 7.38 s
#
#  <class 'genomic.sequence.Dna2VecProcessor'>
# CPU times: user 1min 1s, sys: 888 ms, total: 1min 2s
# Wall time: 1min 2s

# %% [markdown]
# ### Create Dendrogram

# %%
def log_scale(X):
    x=np.asarray(X);e=1e-6
    return np.log10(x+np.abs(x.min())+e) 


x=np.asarray(data.items)
bad_fastas = np.where(np.mean(x,axis=1) == 0.)[0]
X = np.delete(x, bad_fastas,0)
labelList=[" ".join(i.split()[1:3]) for i in data.descriptions]
labelList=np.delete(np.asarray(labelList), bad_fastas)
y=labelList

X_df=pd.DataFrame(data=X, index=labelList)

# %%
pd.get_dummies(X_df.index).iloc[0]
# Out:
# Bacillus andreraoultii,            0
# Bacillus cereus                    0
# Bacillus coahuilensis              0
# Bacillus eiseniae                  0
# Bacillus krulwichiae               0
# Bacillus mannanilyticus            0
# Bacillus massilioanorexius         0
# Bacillus panaciterrae              0
# Bacillus psychrosaccharolyticus    0
# Bacillus solani                    0
# Bacillus subterraneus              0
# Bacillus thermoamylovorans         0
# Bacillus vallismortis              0
# Rhizobium acidisoli                0
# Rhizobium leguminosarum            0
# Rhizobium loessense                0
# Rhizobium sophorae                 0
# Rhizobium tropici                  0
# Rhizobium vignae                   0
# Staphylococcus agnetis             0
# Staphylococcus aureus              0
# Staphylococcus hyicus              0
# Staphylococcus intermedius         0
# Staphylococcus warneri             0
# Staphylococcus xylosus             0
# Streptococcus acidominimus         0
# Streptococcus azizii               0
# Streptococcus entericus            0
# Streptococcus himalayensis         0
# Streptococcus minor                0
# Streptococcus oralis               0
# Streptomyces albidoflavus          0
# Streptomyces ambofaciens           0
# Streptomyces antibioticus          0
# Streptomyces antioxidans           0
# Streptomyces filamentosus          0
# Vibrio aerogenes                   1
# Vibrio celticus                    0
# Vibrio europaeus                   0
# Vibrio ruber                       0
# Vibrio xiamenensis                 0
# Name: 0, dtype: uint8

# %%
linked = linkage(log_scale(X),method="complete", metric="cosine")

fig=plt.figure(figsize=(10, 59)) 
ax1 = fig.add_subplot(111)

htree = dendrogram(linked,  
            ax=ax1,
            orientation='right',
            p=300,
            truncate_mode='lastp',
            leaf_font_size = 10,
            labels=labelList,
            distance_sort='descending',
            show_contracted=True,       
            show_leaf_counts=True)

# %%
linked = linkage(X,method="complete", metric="correlation")

fig=plt.figure(figsize=(10, 59)) 
ax1 = fig.add_subplot(111)

htree = dendrogram(linked,  
            ax=ax1,
            orientation='right',
            p=300,
            truncate_mode='lastp',
            leaf_font_size = 10,
            labels=labelList,
            distance_sort='descending',
            show_contracted=True,       
            show_leaf_counts=True)

# %%
def log_scale(X):
    x=np.asarray(X);e=1e-6
    return np.log10(x+np.abs(x.min())+e) 


x=np.asarray(data.items)
bad_fastas = np.where(np.mean(x,axis=1) == 0.)[0]
X = np.delete(x, bad_fastas,0)
labelList=[" ".join(i.split()[1:3]) for i in data.descriptions]
labelList=np.delete(np.asarray(labelList), bad_fastas)
vocab=list(np.unique(labelList))
y=[vocab.index(x) for x in labelList]

# %%
tsne = manifold.TSNE(n_components=3, init='pca', perplexity=50, metric="correlation",random_state=0)
# %time X3 = tsne.fit_transform(log_scale(X))

genus = [i.split()[0] for i in labelList]
genus_vocab=list(np.unique(genus))
y=[genus_vocab.index(x) for x in genus]
genus_vocab

X3_df = pd.DataFrame(data=X3, columns=["pc1",'pc2','pc3'], index=labelList)

X3_df["genus"]=genus
X3_df["y"]=y

genus_df=X3_df.groupby("genus").agg({"pc1": list, "pc2":list,"pc3":list,"y":np.mean})
# Out:
# CPU times: user 2min 39s, sys: 316 ms, total: 2min 40s
# Wall time: 2min 40s

# %%
data=[]
for g in genus_df.index:
    trace  = go.Scatter3d(
        name = str(g),
        x=genus_df.loc[g,"pc1"],
        y=genus_df.loc[g,"pc2"],
        z=genus_df.loc[g,"pc3"],
        mode='markers',
        marker=dict(
            size=8,
            color=genus_df.loc[g,"y"],                # set color to an array/list of desired values
            colorscale='Jet',           # choose a colorscale
            opacity=0.5)
    )

    data.append(trace)
    

layout = go.Layout(
    width=1299,
    height=1299,
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='correlation distance ncbi-genomes-2019-04-07 Escherichia,Klebsiella,Bacillus')
# Out:
# /home/serge/.local/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sergeman/12.embed" height="1299px" width="1299px"></iframe>

# %%
tsne = manifold.TSNE(init='pca', metric="l2",random_state=0)
X_tsne = tsne.fit_transform(X)

fig = plt.figure(figsize=(30,30))
ax = fig.add_subplot(111)
for i in range(X_tsne.shape[0]):
    if "Bacillus" in labelList[i]:
        plt.scatter(x=X_log_tsne[i,0],y=X_log_tsne[i,1],marker=".",s=200,color="g",alpha=.25)
    if "Streptomyces" in labelList[i]:
        plt.scatter(x=X_log_tsne[i,0],y=X_log_tsne[i,1],marker=".",s=200,color="r",alpha=.25)
    if "Vibrio" in labelList[i]:
        plt.scatter(x=X_log_tsne[i,0],y=X_log_tsne[i,1],marker=".",s=200,color="b",alpha=.25)
    if "Streptococcus" in labelList[i]:
        plt.scatter(x=X_log_tsne[i,0],y=X_log_tsne[i,1],marker=".",s=200,color="k",alpha=.25)
    if "Rhizobium" in labelList[i]:
        plt.scatter(x=X_log_tsne[i,0],y=X_log_tsne[i,1],marker="s",s=100,color="maroon",alpha=.25)
    if "Staphylococcus" in labelList[i]:
        plt.scatter(x=X_log_tsne[i,0],y=X_log_tsne[i,1],marker="v",s=100,color="blueviolet",alpha=.25)
        
plt.show()

# %%
tsne = manifold.TSNE(init='pca',metric="cosine",random_state=0)
X_tsne = tsne.fit_transform(X)

outliers = np.sum((abs(X_tsne) > np.std(X_tsne, axis=0)),axis=1) > 0

X_tsne[outliers,]=np.mean(X_tsne, axis=0)

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111)
for i in range(X_tsne.shape[0]):
    if "Bacillus" in labelList[i]:
        plt.scatter(x=X_tsne[i,0],y=X_tsne[i,1],marker=".",s=200,color="g",alpha=.25)
    if "Streptomyces" in labelList[i]:
        plt.scatter(x=X_tsne[i,0],y=X_tsne[i,1],marker=".",s=200,color="r",alpha=.25)
    if "Vibrio" in labelList[i]:
        plt.scatter(x=X_tsne[i,0],y=X_tsne[i,1],marker=".",s=200,color="b",alpha=.25)
    if "Streptococcus" in labelList[i]:
        plt.scatter(x=X_tsne[i,0],y=X_tsne[i,1],marker=".",s=200,color="k",alpha=.25)
    if "Rhizobium" in labelList[i]:
        plt.scatter(x=X_tsne[i,0],y=X_tsne[i,1],marker="s",s=100,color="maroon",alpha=.25)
    if "Staphylococcus" in labelList[i]:
        plt.scatter(x=X_tsne[i,0],y=X_tsne[i,1],marker="v",s=200,color="blueviolet",alpha=.25)
        
plt.show()

# %%
df=

# %%
sorted(neighbors.VALID_METRICS['brute'])
# Out:
# ['braycurtis',
#  'canberra',
#  'chebyshev',
#  'cityblock',
#  'correlation',
#  'cosine',
#  'cosine',
#  'dice',
#  'euclidean',
#  'hamming',
#  'jaccard',
#  'kulsinski',
#  'l1',
#  'l2',
#  'mahalanobis',
#  'manhattan',
#  'matching',
#  'minkowski',
#  'precomputed',
#  'rogerstanimoto',
#  'russellrao',
#  'seuclidean',
#  'sokalmichener',
#  'sokalsneath',
#  'sqeuclidean',
#  'wminkowski',
#  'yule']

# %%
nunique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ccf4db7699f7> in <module>
# ----> 1 nunique
#
# NameError: name 'nunique' is not defined

# %%
all_fastas = sequence.Dna2VecList.from_folder("/data/genomes/GenSeq_fastas/train").descriptions
inventory = pd.DataFrame(data=[l.split()[1:3] for l in all_fastas], columns=["genus","species" ]).groupby(["genus", "species"]).agg({"species": "count"})
inventory.columns=["count"]
inventory
# Out:
#                                          count
# genus            species
# Bacillus         cereus                      2
#                  coahuilensis              138
#                  eiseniae                    9
#                  krulwichiae                 1
#                  mannanilyticus            108
#                  massilioanorexius         120
#                  panaciterrae              189
#                  psychrosaccharolyticus    265
#                  solani                     12
#                  subterraneus              208
#                  vallismortis               80
# Clostridium      aceticum                    2
#                  amylolyticum               20
#                  butyricum                   2
#                  chauvoei                    1
#                  haemolyticum              234
# Corynebacterium  accolens                   38
#                  atypicum                    2
#                  doosanense                  2
#                  genitalium                  1
#                  glucuronolyticum           41
#                  imitans                     1
#                  timonense                  18
# Enterobacter     aerogenes                   1
# Escherichia      albertii                    1
#                  fergusonii                  2
#                  marmotae                  130
# Klebsiella       oxytoca                    12
#                  quasipneumoniae             3
#                  variicola                   1
# ...                                        ...
# Shigella         boydii                      6
#                  dysenteriae                 3
#                  sonnei                      5
# Staphylococcus   agnetis                     2
#                  aureus                      1
#                  hyicus                      1
#                  intermedius               286
#                  warneri                     9
#                  xylosus                     2
# Stenotrophomonas acidaminiphila              1
#                  ginsengisoli               99
#                  koreensis                  58
#                  pavanii                    17
#                  rhizophila                  1
# Streptococcus    acidominimus              111
#                  azizii                     43
#                  entericus                  33
#                  himalayensis                1
#                  minor                      33
#                  oralis                      1
# Streptomyces     albidoflavus              115
#                  ambofaciens                 2
#                  antibioticus              343
#                  antioxidans               282
#                  filamentosus                1
# Vibrio           aerogenes                  77
#                  celticus                  196
#                  europaeus                  10
#                  ruber                     103
#                  xiamenensis                82
#
# [88 rows x 1 columns]

# %%
counts = inventory.reset_index().groupby("genus").agg({"count", sum}).drop(("species"), axis=1)
counts.columns=["species","sequences"]

# %%
counts.sort_values("sequences", ascending=False)
# Out:
#                   species  sequences
# genus
# Bacillus               11       1132
# Streptomyces            5        743
# Vibrio                  5        468
# Rhizobium               6        325
# Pseudomonas             8        304
# Staphylococcus          6        301
# Clostridium             5        259
# Streptococcus           6        222
# Planktothrix            5        179
# Stenotrophomonas        5        176
# Escherichia             3        133
# Paenibacillus           3        127
# Listeria                4        104
# Corynebacterium         7        103
# Klebsiella              3         16
# Shigella                3         14
# Salmonella              2          4
# Enterobacter            1          1

# %%
[i.split()[1:3] for i in all_fastas if  "plasmid" in i]
# Out:
# [['Staphylococcus', 'agnetis'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Klebsiella', 'oxytoca'],
#  ['Vibrio', 'europaeus'],
#  ['Vibrio', 'europaeus'],
#  ['Staphylococcus', 'xylosus'],
#  ['Staphylococcus', 'warneri'],
#  ['Staphylococcus', 'warneri'],
#  ['Staphylococcus', 'warneri'],
#  ['Staphylococcus', 'warneri'],
#  ['Staphylococcus', 'warneri'],
#  ['Staphylococcus', 'warneri'],
#  ['Staphylococcus', 'warneri'],
#  ['Staphylococcus', 'warneri'],
#  ['Corynebacterium', 'atypicum'],
#  ['Rhizobium', 'leguminosarum'],
#  ['Rhizobium', 'leguminosarum'],
#  ['Rhizobium', 'leguminosarum'],
#  ['Rhizobium', 'leguminosarum'],
#  ['Rhizobium', 'leguminosarum'],
#  ['Clostridium', 'aceticum'],
#  ['Shigella', 'sonnei'],
#  ['Shigella', 'sonnei'],
#  ['Shigella', 'sonnei'],
#  ['Shigella', 'sonnei'],
#  ['Streptomyces', 'ambofaciens'],
#  ['Escherichia', 'fergusonii'],
#  ['Salmonella', 'enterica'],
#  ['Salmonella', 'enterica'],
#  ['Rhizobium', 'tropici'],
#  ['Rhizobium', 'tropici'],
#  ['Rhizobium', 'tropici'],
#  ['Shigella', 'boydii'],
#  ['Shigella', 'boydii'],
#  ['Shigella', 'boydii'],
#  ['Shigella', 'boydii'],
#  ['Shigella', 'boydii'],
#  ['Klebsiella', 'quasipneumoniae'],
#  ['Klebsiella', 'quasipneumoniae'],
#  ['Bacillus', 'cereus'],
#  ['Planktothrix', 'agardhii'],
#  ['Planktothrix', 'agardhii'],
#  ['Planktothrix', 'agardhii'],
#  ['Planktothrix', 'agardhii'],
#  ['Planktothrix', 'agardhii'],
#  ['Paenibacillus', 'alvei'],
#  ['Paenibacillus', 'alvei'],
#  ['Paenibacillus', 'alvei'],
#  ['Paenibacillus', 'alvei'],
#  ['Corynebacterium', 'doosanense'],
#  ['Shigella', 'dysenteriae'],
#  ['Shigella', 'dysenteriae']]

# %% [markdown]
# ### New heading
