# %% [markdown]
# ## Hierarchial clustering of genomes vectorized using dna2vec embedding
#
# Vectorisation of a genome using average embedding vectors for 8-grams
#
# Phylogenic tree is a dendrogrm of hierarchical clustering of genomes (I think :)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../mylib/")

from genomic import sequence
from genomic.sequence import regex_filter, count_filter
from functools import partial
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import manifold
from scipy.cluster.hierarchy import dendrogram, linkage  
from matplotlib import pyplot as plt
import seaborn as sns; sns.set(color_codes=True)

# %% [markdown]
# ### Load Data

# %%
filters=[partial(regex_filter, rx="Pseudomonas"),
         partial(count_filter, max_count=599)]
data = sequence.Dna2VecList.from_folder("/data/genomes/GenSeq_fastas/train",filters=filters,agg=partial(np.mean, axis=0),n_cpus=7)
processors = [
    sequence.GSFileProcessor(),
    sequence.GSTokenizeProcessor(tokenizer=sequence.GSTokenizer(ngram=8, skip=-7, n_cpus=7)),
    sequence.Dna2VecProcessor()]
# %time for p in processors: p.process(data)
# Out:
# CPU times: user 1min 51s, sys: 5.08 s, total: 1min 56s
# Wall time: 2min 5s

# %%
len(data.items)
# Out:
# 304

# %%
data.descriptions
# Out:
# ['NZ_JXDG01000001.1 Pseudomonas batumici strain UCM B-321 Contig_1, whole genome shotgun sequence',
#  'NZ_JXDG01000010.1 Pseudomonas batumici strain UCM B-321 Contig_10, whole genome shotgun sequence',
#  'NZ_JXDG01000100.1 Pseudomonas batumici strain UCM B-321 Contig_100, whole genome shotgun sequence',
#  'NZ_JXDG01000101.1 Pseudomonas batumici strain UCM B-321 Contig_101, whole genome shotgun sequence',
#  'NZ_JXDG01000102.1 Pseudomonas batumici strain UCM B-321 Contig_102, whole genome shotgun sequence',
#  'NZ_JXDG01000103.1 Pseudomonas batumici strain UCM B-321 Contig_103, whole genome shotgun sequence',
#  'NZ_JXDG01000104.1 Pseudomonas batumici strain UCM B-321 Contig_104, whole genome shotgun sequence',
#  'NZ_JXDG01000105.1 Pseudomonas batumici strain UCM B-321 Contig_105, whole genome shotgun sequence',
#  'NZ_JXDG01000106.1 Pseudomonas batumici strain UCM B-321 Contig_106, whole genome shotgun sequence',
#  'NZ_JXDG01000107.1 Pseudomonas batumici strain UCM B-321 Contig_107, whole genome shotgun sequence',
#  'NZ_JXDG01000108.1 Pseudomonas batumici strain UCM B-321 Contig_108, whole genome shotgun sequence',
#  'NZ_JXDG01000109.1 Pseudomonas batumici strain UCM B-321 Contig_109, whole genome shotgun sequence',
#  'NZ_JXDG01000011.1 Pseudomonas batumici strain UCM B-321 Contig_11, whole genome shotgun sequence',
#  'NZ_JXDG01000110.1 Pseudomonas batumici strain UCM B-321 Contig_110, whole genome shotgun sequence',
#  'NZ_JXDG01000111.1 Pseudomonas batumici strain UCM B-321 Contig_111, whole genome shotgun sequence',
#  'NZ_JXDG01000112.1 Pseudomonas batumici strain UCM B-321 Contig_112, whole genome shotgun sequence',
#  'NZ_JXDG01000113.1 Pseudomonas batumici strain UCM B-321 Contig_114, whole genome shotgun sequence',
#  'NZ_JXDG01000114.1 Pseudomonas batumici strain UCM B-321 Contig_115, whole genome shotgun sequence',
#  'NZ_JXDG01000115.1 Pseudomonas batumici strain UCM B-321 Contig_116, whole genome shotgun sequence',
#  'NZ_JXDG01000116.1 Pseudomonas batumici strain UCM B-321 Contig_117, whole genome shotgun sequence',
#  'NZ_JXDG01000117.1 Pseudomonas batumici strain UCM B-321 Contig_118, whole genome shotgun sequence',
#  'NZ_JXDG01000118.1 Pseudomonas batumici strain UCM B-321 Contig_119, whole genome shotgun sequence',
#  'NZ_JXDG01000012.1 Pseudomonas batumici strain UCM B-321 Contig_12, whole genome shotgun sequence',
#  'NZ_JXDG01000119.1 Pseudomonas batumici strain UCM B-321 Contig_120, whole genome shotgun sequence',
#  'NZ_JXDG01000120.1 Pseudomonas batumici strain UCM B-321 Contig_121, whole genome shotgun sequence',
#  'NZ_JXDG01000121.1 Pseudomonas batumici strain UCM B-321 Contig_122, whole genome shotgun sequence',
#  'NZ_JXDG01000122.1 Pseudomonas batumici strain UCM B-321 Contig_123, whole genome shotgun sequence',
#  'NZ_JXDG01000123.1 Pseudomonas batumici strain UCM B-321 Contig_124, whole genome shotgun sequence',
#  'NZ_JXDG01000124.1 Pseudomonas batumici strain UCM B-321 Contig_125, whole genome shotgun sequence',
#  'NZ_JXDG01000125.1 Pseudomonas batumici strain UCM B-321 Contig_126, whole genome shotgun sequence',
#  'NZ_JXDG01000126.1 Pseudomonas batumici strain UCM B-321 Contig_127, whole genome shotgun sequence',
#  'NZ_JXDG01000013.1 Pseudomonas batumici strain UCM B-321 Contig_13, whole genome shotgun sequence',
#  'NZ_JXDG01000014.1 Pseudomonas batumici strain UCM B-321 Contig_14, whole genome shotgun sequence',
#  'NZ_JXDG01000015.1 Pseudomonas batumici strain UCM B-321 Contig_15, whole genome shotgun sequence',
#  'NZ_JXDG01000016.1 Pseudomonas batumici strain UCM B-321 Contig_16, whole genome shotgun sequence',
#  'NZ_JXDG01000017.1 Pseudomonas batumici strain UCM B-321 Contig_17, whole genome shotgun sequence',
#  'NZ_JXDG01000018.1 Pseudomonas batumici strain UCM B-321 Contig_18, whole genome shotgun sequence',
#  'NZ_JXDG01000019.1 Pseudomonas batumici strain UCM B-321 Contig_19, whole genome shotgun sequence',
#  'NZ_JXDG01000002.1 Pseudomonas batumici strain UCM B-321 Contig_2, whole genome shotgun sequence',
#  'NZ_JXDG01000020.1 Pseudomonas batumici strain UCM B-321 Contig_20, whole genome shotgun sequence',
#  'NZ_JXDG01000021.1 Pseudomonas batumici strain UCM B-321 Contig_21, whole genome shotgun sequence',
#  'NZ_JXDG01000022.1 Pseudomonas batumici strain UCM B-321 Contig_22, whole genome shotgun sequence',
#  'NZ_JXDG01000023.1 Pseudomonas batumici strain UCM B-321 Contig_23, whole genome shotgun sequence',
#  'NZ_JXDG01000024.1 Pseudomonas batumici strain UCM B-321 Contig_24, whole genome shotgun sequence',
#  'NZ_JXDG01000025.1 Pseudomonas batumici strain UCM B-321 Contig_25, whole genome shotgun sequence',
#  'NZ_JXDG01000026.1 Pseudomonas batumici strain UCM B-321 Contig_26, whole genome shotgun sequence',
#  'NZ_JXDG01000027.1 Pseudomonas batumici strain UCM B-321 Contig_27, whole genome shotgun sequence',
#  'NZ_JXDG01000028.1 Pseudomonas batumici strain UCM B-321 Contig_28, whole genome shotgun sequence',
#  'NZ_JXDG01000029.1 Pseudomonas batumici strain UCM B-321 Contig_29, whole genome shotgun sequence',
#  'NZ_JXDG01000003.1 Pseudomonas batumici strain UCM B-321 Contig_3, whole genome shotgun sequence',
#  'NZ_JXDG01000030.1 Pseudomonas batumici strain UCM B-321 Contig_30, whole genome shotgun sequence',
#  'NZ_JXDG01000031.1 Pseudomonas batumici strain UCM B-321 Contig_31, whole genome shotgun sequence',
#  'NZ_JXDG01000032.1 Pseudomonas batumici strain UCM B-321 Contig_32, whole genome shotgun sequence',
#  'NZ_JXDG01000033.1 Pseudomonas batumici strain UCM B-321 Contig_33, whole genome shotgun sequence',
#  'NZ_JXDG01000034.1 Pseudomonas batumici strain UCM B-321 Contig_34, whole genome shotgun sequence',
#  'NZ_JXDG01000035.1 Pseudomonas batumici strain UCM B-321 Contig_35, whole genome shotgun sequence',
#  'NZ_JXDG01000036.1 Pseudomonas batumici strain UCM B-321 Contig_36, whole genome shotgun sequence',
#  'NZ_JXDG01000037.1 Pseudomonas batumici strain UCM B-321 Contig_37, whole genome shotgun sequence',
#  'NZ_JXDG01000038.1 Pseudomonas batumici strain UCM B-321 Contig_38, whole genome shotgun sequence',
#  'NZ_JXDG01000039.1 Pseudomonas batumici strain UCM B-321 Contig_39, whole genome shotgun sequence',
#  'NZ_JXDG01000004.1 Pseudomonas batumici strain UCM B-321 Contig_4, whole genome shotgun sequence',
#  'NZ_JXDG01000040.1 Pseudomonas batumici strain UCM B-321 Contig_40, whole genome shotgun sequence',
#  'NZ_JXDG01000041.1 Pseudomonas batumici strain UCM B-321 Contig_41, whole genome shotgun sequence',
#  'NZ_JXDG01000042.1 Pseudomonas batumici strain UCM B-321 Contig_42, whole genome shotgun sequence',
#  'NZ_JXDG01000043.1 Pseudomonas batumici strain UCM B-321 Contig_43, whole genome shotgun sequence',
#  'NZ_JXDG01000044.1 Pseudomonas batumici strain UCM B-321 Contig_44, whole genome shotgun sequence',
#  'NZ_JXDG01000045.1 Pseudomonas batumici strain UCM B-321 Contig_45, whole genome shotgun sequence',
#  'NZ_JXDG01000046.1 Pseudomonas batumici strain UCM B-321 Contig_46, whole genome shotgun sequence',
#  'NZ_JXDG01000047.1 Pseudomonas batumici strain UCM B-321 Contig_47, whole genome shotgun sequence',
#  'NZ_JXDG01000048.1 Pseudomonas batumici strain UCM B-321 Contig_48, whole genome shotgun sequence',
#  'NZ_JXDG01000049.1 Pseudomonas batumici strain UCM B-321 Contig_49, whole genome shotgun sequence',
#  'NZ_JXDG01000005.1 Pseudomonas batumici strain UCM B-321 Contig_5, whole genome shotgun sequence',
#  'NZ_JXDG01000050.1 Pseudomonas batumici strain UCM B-321 Contig_50, whole genome shotgun sequence',
#  'NZ_JXDG01000051.1 Pseudomonas batumici strain UCM B-321 Contig_51, whole genome shotgun sequence',
#  'NZ_JXDG01000052.1 Pseudomonas batumici strain UCM B-321 Contig_52, whole genome shotgun sequence',
#  'NZ_JXDG01000053.1 Pseudomonas batumici strain UCM B-321 Contig_53, whole genome shotgun sequence',
#  'NZ_JXDG01000054.1 Pseudomonas batumici strain UCM B-321 Contig_54, whole genome shotgun sequence',
#  'NZ_JXDG01000055.1 Pseudomonas batumici strain UCM B-321 Contig_55, whole genome shotgun sequence',
#  'NZ_JXDG01000056.1 Pseudomonas batumici strain UCM B-321 Contig_56, whole genome shotgun sequence',
#  'NZ_JXDG01000057.1 Pseudomonas batumici strain UCM B-321 Contig_57, whole genome shotgun sequence',
#  'NZ_JXDG01000058.1 Pseudomonas batumici strain UCM B-321 Contig_58, whole genome shotgun sequence',
#  'NZ_JXDG01000059.1 Pseudomonas batumici strain UCM B-321 Contig_59, whole genome shotgun sequence',
#  'NZ_JXDG01000006.1 Pseudomonas batumici strain UCM B-321 Contig_6, whole genome shotgun sequence',
#  'NZ_JXDG01000060.1 Pseudomonas batumici strain UCM B-321 Contig_60, whole genome shotgun sequence',
#  'NZ_JXDG01000061.1 Pseudomonas batumici strain UCM B-321 Contig_61, whole genome shotgun sequence',
#  'NZ_JXDG01000062.1 Pseudomonas batumici strain UCM B-321 Contig_62, whole genome shotgun sequence',
#  'NZ_JXDG01000063.1 Pseudomonas batumici strain UCM B-321 Contig_63, whole genome shotgun sequence',
#  'NZ_JXDG01000064.1 Pseudomonas batumici strain UCM B-321 Contig_64, whole genome shotgun sequence',
#  'NZ_JXDG01000065.1 Pseudomonas batumici strain UCM B-321 Contig_65, whole genome shotgun sequence',
#  'NZ_JXDG01000066.1 Pseudomonas batumici strain UCM B-321 Contig_66, whole genome shotgun sequence',
#  'NZ_JXDG01000067.1 Pseudomonas batumici strain UCM B-321 Contig_67, whole genome shotgun sequence',
#  'NZ_JXDG01000068.1 Pseudomonas batumici strain UCM B-321 Contig_68, whole genome shotgun sequence',
#  'NZ_JXDG01000069.1 Pseudomonas batumici strain UCM B-321 Contig_69, whole genome shotgun sequence',
#  'NZ_JXDG01000007.1 Pseudomonas batumici strain UCM B-321 Contig_7, whole genome shotgun sequence',
#  'NZ_JXDG01000070.1 Pseudomonas batumici strain UCM B-321 Contig_70, whole genome shotgun sequence',
#  'NZ_JXDG01000071.1 Pseudomonas batumici strain UCM B-321 Contig_71, whole genome shotgun sequence',
#  'NZ_JXDG01000072.1 Pseudomonas batumici strain UCM B-321 Contig_72, whole genome shotgun sequence',
#  'NZ_JXDG01000073.1 Pseudomonas batumici strain UCM B-321 Contig_73, whole genome shotgun sequence',
#  'NZ_JXDG01000074.1 Pseudomonas batumici strain UCM B-321 Contig_74, whole genome shotgun sequence',
#  'NZ_JXDG01000075.1 Pseudomonas batumici strain UCM B-321 Contig_75, whole genome shotgun sequence',
#  'NZ_JXDG01000076.1 Pseudomonas batumici strain UCM B-321 Contig_76, whole genome shotgun sequence',
#  'NZ_JXDG01000077.1 Pseudomonas batumici strain UCM B-321 Contig_77, whole genome shotgun sequence',
#  'NZ_JXDG01000078.1 Pseudomonas batumici strain UCM B-321 Contig_78, whole genome shotgun sequence',
#  'NZ_JXDG01000079.1 Pseudomonas batumici strain UCM B-321 Contig_79, whole genome shotgun sequence',
#  'NZ_JXDG01000008.1 Pseudomonas batumici strain UCM B-321 Contig_8, whole genome shotgun sequence',
#  'NZ_JXDG01000080.1 Pseudomonas batumici strain UCM B-321 Contig_80, whole genome shotgun sequence',
#  'NZ_JXDG01000081.1 Pseudomonas batumici strain UCM B-321 Contig_81, whole genome shotgun sequence',
#  'NZ_JXDG01000082.1 Pseudomonas batumici strain UCM B-321 Contig_82, whole genome shotgun sequence',
#  'NZ_JXDG01000083.1 Pseudomonas batumici strain UCM B-321 Contig_83, whole genome shotgun sequence',
#  'NZ_JXDG01000084.1 Pseudomonas batumici strain UCM B-321 Contig_84, whole genome shotgun sequence',
#  'NZ_JXDG01000085.1 Pseudomonas batumici strain UCM B-321 Contig_85, whole genome shotgun sequence',
#  'NZ_JXDG01000086.1 Pseudomonas batumici strain UCM B-321 Contig_86, whole genome shotgun sequence',
#  'NZ_JXDG01000087.1 Pseudomonas batumici strain UCM B-321 Contig_87, whole genome shotgun sequence',
#  'NZ_JXDG01000088.1 Pseudomonas batumici strain UCM B-321 Contig_88, whole genome shotgun sequence',
#  'NZ_JXDG01000089.1 Pseudomonas batumici strain UCM B-321 Contig_89, whole genome shotgun sequence',
#  'NZ_JXDG01000009.1 Pseudomonas batumici strain UCM B-321 Contig_9, whole genome shotgun sequence',
#  'NZ_JXDG01000090.1 Pseudomonas batumici strain UCM B-321 Contig_90, whole genome shotgun sequence',
#  'NZ_JXDG01000091.1 Pseudomonas batumici strain UCM B-321 Contig_91, whole genome shotgun sequence',
#  'NZ_JXDG01000092.1 Pseudomonas batumici strain UCM B-321 Contig_92, whole genome shotgun sequence',
#  'NZ_JXDG01000093.1 Pseudomonas batumici strain UCM B-321 Contig_93, whole genome shotgun sequence',
#  'NZ_JXDG01000094.1 Pseudomonas batumici strain UCM B-321 Contig_94, whole genome shotgun sequence',
#  'NZ_JXDG01000095.1 Pseudomonas batumici strain UCM B-321 Contig_95, whole genome shotgun sequence',
#  'NZ_JXDG01000096.1 Pseudomonas batumici strain UCM B-321 Contig_96, whole genome shotgun sequence',
#  'NZ_JXDG01000097.1 Pseudomonas batumici strain UCM B-321 Contig_97, whole genome shotgun sequence',
#  'NZ_JXDG01000098.1 Pseudomonas batumici strain UCM B-321 Contig_98, whole genome shotgun sequence',
#  'NZ_JXDG01000099.1 Pseudomonas batumici strain UCM B-321 Contig_99, whole genome shotgun sequence',
#  'NZ_FOWX01000096.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000092.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000089.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000085.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000084.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000095.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000083.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000087.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000081.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000080.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000079.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000082.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000077.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000070.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000073.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000069.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000065.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000076.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000063.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000062.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000061.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000057.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000055.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000054.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000053.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000074.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000072.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000052.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000068.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000051.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000050.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000090.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000049.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000064.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000022.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000020.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000078.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000014.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000013.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000019.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000086.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000017.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000048.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000011.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000091.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000028.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000094.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000001.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000045.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000071.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000006.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000012.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000036.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000008.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000018.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000005.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000031.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000003.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000004.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000007.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000021.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000015.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000009.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000067.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000016.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000093.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000088.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000029.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000030.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000025.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000058.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000010.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000039.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000041.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000023.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000024.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000026.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000027.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000032.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000047.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000033.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000034.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000037.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000038.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000075.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000060.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000035.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000040.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000056.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000002.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000042.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000059.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000043.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000066.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000044.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FOWX01000046.1 Pseudomonas borbori strain DSM 17834, whole genome shotgun sequence',
#  'NZ_FNTS01000002.1 Pseudomonas costantinii strain BS2773, whole genome shotgun sequence',
#  'NZ_FNTS01000001.1 Pseudomonas costantinii strain BS2773, whole genome shotgun sequence',
#  'NZ_CP016162.1 Pseudomonas alcaliphila JAB1 chromosome, complete genome',
#  'NZ_CP007039.1 Pseudomonas cichorii JBC1, complete genome',
#  'NZ_FNJH01000010.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000004.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000008.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000017.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000021.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000009.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000003.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000023.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000002.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000022.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000016.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000019.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000005.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000012.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000018.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000006.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000001.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000011.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000014.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000007.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000013.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000015.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_FNJH01000020.1 Pseudomonas congelans strain DSM 14939, whole genome shotgun sequence',
#  'NZ_LT629777.1 Pseudomonas asplenii strain ATCC 23835 genome assembly, chromosome: I',
#  'NZ_FNCO01000054.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000053.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000049.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000037.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000012.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000047.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000028.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000014.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000051.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000011.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000018.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000034.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000044.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000001.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000016.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000005.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000017.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000042.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000015.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000013.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000019.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000009.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000002.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000007.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000020.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000003.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000004.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000023.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000006.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000035.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000036.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000038.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000024.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000046.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000025.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000026.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000008.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000027.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000029.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000039.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000030.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000021.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000032.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000033.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000040.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000022.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000010.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000041.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000050.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000048.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000043.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000052.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000031.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence',
#  'NZ_FNCO01000045.1 Pseudomonas abietaniphila strain ATCC 700689, whole genome shotgun sequence']

# %% [markdown]
# ### Create Dendrogram

# %%
def log_scale(X):
    x=np.asarray(X);e=1e-6
    return np.log10(x+np.abs(x.min())+e) 


x=np.asarray(data.items)
bad_fastas = np.where(np.mean(x,axis=1) == 0.)[0]
X = np.delete(x, bad_fastas,0)
labelList=[" ".join(i.split()[2]) for i in data.descriptions]
labelList=np.delete(np.asarray(labelList), bad_fastas)
y=labelList

X_df=pd.DataFrame(data=log_scale(X), index=labelList)

# %%
linked = linkage(X_df, method='ward')

plt.figure(figsize=(20, 20))  
htree = dendrogram(linked,  
            orientation='right',
            p=50,
            truncate_mode='lastp',
            leaf_font_size = 10,
            labels=labelList,
            distance_sort='descending',
            show_contracted=True,       
            show_leaf_counts=False)
plt.show()

# %%
pca = PCA(n_components=10)
pc = pca.fit_transform(X)


plt.figure(figsize=(20, 20))  
htree = dendrogram(linkage(log_scale(pc), method='ward'),  
            orientation='right',
            p=50,
            truncate_mode='lastp',
            leaf_font_size = 8,
            labels=labelList,
            distance_sort='descending',
            show_contracted=True,       
            show_leaf_counts=False)
plt.show()

# %%
tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
X_tsne = tsne.fit_transform(log_scale(X))

vocab=list(np.unique(labelList))
y=[vocab.index(x) for x in labelList]

colors = plt.cm.Set1(range(len(vocab)))

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111)
for i in range(X_tsne.shape[0]):    
    plt.scatter(x=X_tsne[i,0],y=X_tsne[i,1],marker=".",s=500,color=colors[y[i]],alpha=.5)
plt.show()

# %%
all_fastas = sequence.Dna2VecList.from_folder("/data/genomes/GenSeq_fastas/train").descriptions
inventory = pd.DataFrame(data=[l.split()[1:3] for l in all_fastas], columns=["genus","species" ]).groupby(["genus", "species"]).agg({"species": "count"})
inventory.columns=["count"]
inventory
# Out:
#                                          count
# genus            species
# Bacillus         cereus                      2
#                  coahuilensis              138
#                  eiseniae                    9
#                  krulwichiae                 1
#                  mannanilyticus            108
#                  massilioanorexius         120
#                  panaciterrae              189
#                  psychrosaccharolyticus    265
#                  solani                     12
#                  subterraneus              208
#                  vallismortis               80
# Clostridium      aceticum                    2
#                  amylolyticum               20
#                  butyricum                   2
#                  chauvoei                    1
#                  haemolyticum              234
# Corynebacterium  accolens                   38
#                  atypicum                    2
#                  doosanense                  2
#                  genitalium                  1
#                  glucuronolyticum           41
#                  imitans                     1
#                  timonense                  18
# Enterobacter     aerogenes                   1
# Escherichia      albertii                    1
#                  fergusonii                  2
#                  marmotae                  130
# Klebsiella       oxytoca                    12
#                  quasipneumoniae             3
#                  variicola                   1
# ...                                        ...
# Shigella         boydii                      6
#                  dysenteriae                 3
#                  sonnei                      5
# Staphylococcus   agnetis                     2
#                  aureus                      1
#                  hyicus                      1
#                  intermedius               286
#                  warneri                     9
#                  xylosus                     2
# Stenotrophomonas acidaminiphila              1
#                  ginsengisoli               99
#                  koreensis                  58
#                  pavanii                    17
#                  rhizophila                  1
# Streptococcus    acidominimus              111
#                  azizii                     43
#                  entericus                  33
#                  himalayensis                1
#                  minor                      33
#                  oralis                      1
# Streptomyces     albidoflavus              115
#                  ambofaciens                 2
#                  antibioticus              343
#                  antioxidans               282
#                  filamentosus                1
# Vibrio           aerogenes                  77
#                  celticus                  196
#                  europaeus                  10
#                  ruber                     103
#                  xiamenensis                82
#
# [88 rows x 1 columns]
